# %%
import numpy
import scipy
from scipy import ndimage
from matplotlib import pyplot as plt
import os
dir = r'C:\Users\Josh\Aaron\storm-control\storm_control\sc_hardware\utility'
os.chdir(dir)
print('current working directory is: ' + dir)
# Out:
# current working directory is: C:\Users\Josh\Aaron\storm-control\storm_control\sc_hardware\utility

# %%
data = scipy.ndimage.imread('testframe.tif')
# Out:
# C:\Users\Josh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
data = plt.imread('testframe.tif')

# %%
data.shape
# Out:
# (350, 350)

# %%
plt.imshow(data)
